# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251124/blob/main/tibame20251203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# 找到網址SOP
# 1. 右鍵-> 打開原始碼
# 2. 如果原始碼有 網址=網址列  沒有 網址=F12找隱藏網址
#
# HTML格式: 一個一個區塊所構成
# <a href="網址" class="">
#     Sujita
# </a>
#
# 1. 區塊名稱: 決定這個區塊是拿來幹嘛的
# a: 超連結 img: 圖片  video: 影片
#
# 2. 屬性: 跟名稱搭配特殊屬性, 決定細節
# a href="網址"
# img/video src="網址"
#
# 3. 顯示內容:
#
# 前端: 1. HTML: 網頁內容  2. CSS: 網頁排版(o)  3. JavsScript: 網頁動態(x)
# 後端: 1. 接收網址 2. 處理網址(SQL...) 3. 送回回覆
# Flask/Django/FastAPI
#
# CSS語法: 找到HTML區塊並且加上排版
# 1. 透過區塊名稱
# a{
#     background-color:pink
# }
#
# 給出一個特殊的HTML屬性 class="分類1 分類2 分類3"
# 2. 透過class屬性
# .分類名稱{
#
# }
# .js-thumbnail-img{
#     border-radius:20px
#     border-radius:50%
# }
#
# (以後有機會用到) 特殊的HTML屬性 id="id名"
# 3. 透過id屬性
# #id名{
#
# }
# ```

# %%
# BeautifulSoup4
import bs4 as bs
import urllib.request as req

url = "https://tabelog.com/tw/tokyo/rstLst/cake/1/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)

# find find_all (區塊html名稱, 篩選條件)
target = html.find("a", {"class":"list-rst__rst-name-target"})
# 萃取東西
# 1. 特殊屬性(字典): 區塊[屬姓名]
# 型態可以擁有兩種東西 1. 專屬功能(f.read()) 2. 專屬值(人.身高)
# 2. 顯示內容: 區塊.text   區塊.get_text()
print(target["href"])
print(target.text)
print(target.get_text())
# Out:
# https://tabelog.com/tw/tokyo/A1304/A130401/13184186/
# Bon.nu
# Bon.nu

# %%
# BeautifulSoup4
import bs4 as bs
import urllib.request as req

url = "https://tabelog.com/tw/tokyo/rstLst/cake/1/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)

# list
rs = html.find_all("div", {"class":"list-rst__body"})
for r in rs:
    en = r.find("a", {"class":"list-rst__rst-name-target"})

    en_href = en["href"]
    en_text = en.text

    print(en_text)
    print(en_href)
    print("-" * 30)
# Out:
# Bon.nu
# https://tabelog.com/tw/tokyo/A1304/A130401/13184186/
# ------------------------------
# Okashiya Ucchi
# https://tabelog.com/tw/tokyo/A1309/A130901/13238644/
# ------------------------------
# AIGRE DOUCE
# https://tabelog.com/tw/tokyo/A1305/A130502/13005641/
# ------------------------------
# Patisserie Ryoko
# https://tabelog.com/tw/tokyo/A1316/A131603/13137010/
# ------------------------------
# a tes souhaits!
# https://tabelog.com/tw/tokyo/A1320/A132001/13005853/
# ------------------------------
# patisserie Paris S'eveille
# https://tabelog.com/tw/tokyo/A1317/A131703/13005198/
# ------------------------------
# Frederic Cassel Ginza Mitsukoshi Ten
# https://tabelog.com/tw/tokyo/A1301/A130101/13116839/
# ------------------------------
# Avranches Guesnay
# https://tabelog.com/tw/tokyo/A1310/A131004/13186450/
# ------------------------------
# Ryoura
# https://tabelog.com/tw/tokyo/A1317/A131707/13188208/
# ------------------------------
# Au Bon Vieux Temps Oyamadai Ten
# ...
