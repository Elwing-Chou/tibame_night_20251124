# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251124/blob/main/tibame20251203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# 找到網址SOP
# 1. 右鍵-> 打開原始碼
# 2. 如果原始碼有 網址=網址列  沒有 網址=F12找隱藏網址
#
# HTML格式: 一個一個區塊所構成
# <a href="網址" class="">
#     Sujita
# </a>
#
# 1. 區塊名稱: 決定這個區塊是拿來幹嘛的
# a: 超連結 img: 圖片  video: 影片
#
# 2. 屬性: 跟名稱搭配特殊屬性, 決定細節
# a href="網址"
# img/video src="網址"
#
# 3. 顯示內容:
#
# 前端: 1. HTML: 網頁內容  2. CSS: 網頁排版(o)  3. JavsScript: 網頁動態(x)
# 後端: 1. 接收網址 2. 處理網址(SQL...) 3. 送回回覆
# Flask/Django/FastAPI
#
# CSS語法: 找到HTML區塊並且加上排版
# 1. 透過區塊名稱
# a{
#     background-color:pink
# }
#
# 給出一個特殊的HTML屬性 class="分類1 分類2 分類3"
# 2. 透過class屬性
# .分類名稱{
#
# }
# .js-thumbnail-img{
#     border-radius:20px
#     border-radius:50%
# }
#
# (以後有機會用到) 特殊的HTML屬性 id="id名"
# 3. 透過id屬性
# #id名{
#
# }
# ```

# %%
import urllib.request as req

url = "https://tabelog.com/tw/tokyo/rstLst/cake/1/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
print(content)
# Out:
# b'<!DOCTYPE html>\n<html lang="tw">\n  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">\n    <title>\xe6\x8e\xa8\xe8\x96\xa6\xe9\x81\xa9\xe5\x90\x88\xe5\x9c\xa8\xe6\x9d\xb1\xe4\xba\xac\xe8\x9b\x8b\xe7\xb3\x95 | Tabelog</title>\n    <link href="https://s.tabelog.com/tw/tokyo/rstLst/cake/?SrtT=rt" media="only screen and (max-width: 640px)" rel="alternate" />\n    <meta content="\xe6\x97\xa5\xe6\x9c\xac\xe6\x9c\x80\xe5\xa4\xa7\xe7\x9a\x84\xe7\xbe\x8e\xe9\xa3\x9f\xe7\xb6\xb2\xe7\xab\x99\xe2\x80\x9cTabelog\xe2\x80\x9d\xe5\x88\x97\xe5\x87\xba\xe4\xba\x86\xe5\x9c\xa8\xe6\x9d\xb1\xe4\xba\xac\xe5\x8f\x97\xe6\xad\xa1\xe8\xbf\x8e2,765\xe5\xae\xb6\xe8\x9b\x8b\xe7\xb3\x95\xe3\x80\x82\xe9\x80\x99\xe8\xa3\xa1\xe5\x85\x85\xe6\xbb\xbf\xe4\xba\x86\xe5\x8f\xaa\xe6\x9c\x89\xe5\x9c\xa8Tabelog" name="description" />\n    <meta content="width=1260" name="viewport" />\n    <link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/css/inbound/desktop/application.css?rst-v1-202512031918-bb449e8c975ad7c38c0625baea53c88d45ee74540ad548ed9fbd53b06569eb3c" />\n    <link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/inbound/desktop/object.css?rst-v1-202512031918-7d826142ecde9ac774d5131d7ee6762b36684b1b48d2d1b00af8bb6f3efa7d98" /><link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/css/inbound/desktop/list/list_common.css?rst-v1-202512031918-498f5cba870d993e415741b7b3cbab71a63565607831f9904de37cbade1f4996" /><noscript></noscript><link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/css/restaurant/desktop/list/list_common_noscript.css?rst-v1-202512031918-f023e4d3b009df7585fe9d9cd876558abd98602594a2a231066e63fdd03f10d7" /><link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/lib/jquery-ui-1.12.1.smoothness.custom.min.css?rst-v1-202512031918-c5c60f20207a5470c978a2855615ae604b3b20f88b7a4841de1711c46339e78d" />\n    <link rel="stylesheet" media="all" href="https://tblg.k-img.com/stylesheets/lib/colorbox.css?rst-v1-202512031918-f4cec0ed48e7e3432e067401c68ea1a23d8b239c132f3ab90e4e940e24efb1ee" /><link rel="stylesheet" media="screen" href="https://tblg.k-img.com/stylesheets/lib/jquery.mCustomScrollbar-3.1.5.css?rst-v1-202512031918-e92d6afe5992a919cd673773f06f980339b555174cf0d205d80fe181bd4be6ce" /><script src="https://tblg.k-img.com/javascripts/assets/sentry_initializer.js?rst-v1-202512031918-37124bad7b8a89754b6888742c975d52cca9e41ed9fab39f4275dba8381b7fdb"></script><script src="https://tblg.k-img.com/javascripts/assets/pepper/restaurant-pc/commons.js?rst-v1-202512031918-107d4f8edfe78e39e7f1bbb11f5bb887cc4d76ff32984f55435ec5b36cfc410b"></script><script src="https://tblg.k-img.com/javascripts/assets/pepper/restaurant-pc/rst/inbound_restaurant_list.js?rst-v1-202512031918-12f466f85ddb973727bbe12260ce8e9db028d07e6ecf95bb27b3853cb9c44bd2"></script>\n    <link href="https://tabelog.com/tw/tokyo/rstLst/cake/" rel="canonical" />\n    <script src="https://tblg.k-img.com/javascripts/assets/pepper/restaurant-pc/rst/inbound/inbound_restaurant_list/index.js?rst-v1-202512031918-20ef728a67800636cfdae90788c2a3c387d196050a080013b9ac4f2a92a0707d"></script>\n          <link as="image" href="https://tblg.k-img.com/restaurant/images/Rvw/123880/320x320_square_123880838.jpg" rel="preload" /><script src="//assets.adobedtm.com/3687940b53f7a560587a33c8bb748b9253ff5ea9/satelliteLib-15b13f3fd03e00e11fcd40b9f97c8b58a9ca6e66.js"></script>\n    <link href="https://tabelog.com/tokyo/rstLst/cake/" hreflang="ja" rel="alternate" />\n    <link href="https://tabelog.com/en/tokyo/rstL ...
