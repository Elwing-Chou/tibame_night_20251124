# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251124/blob/main/tibame_night_1124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5

# %% [markdown]
# markdown語法
#
# aaaa
#
# Latex Math
#
# $ 面積 = \frac{1}{4} \pi R^2 $

# %% [markdown]
# ```
# LAB1. 演算法(想法)
#
# 完全平方日: 要從20241001(4499^2)往後列印出10個完全平方日
#
# 想法1: 20241001(可不可以開根號成整數) 20241002 20241003 20241004...
#
# 想法2: 4499*4499(是否是個合法的日期) 4500*4500 4501*4501....
#
# 下一個 20720704(4552*4552)
#
# 想法1: 48(年)*365=17520(次)
# 想法2: 4552-4499=103(次)
#
# 想法2好, 因為化成程式的時候, 可能比想法1跑得快了100倍
#
# 1. while True 往下一直找
# 2. 確定是否合法日期: 年/月/日
#
# 年: > 0
# 月: 12 > > 1
# 日: a. 每個月分不一樣 b. 閏年(2/29)
#
# O: 閏年
# 95(X) 96(o) 97(x) 98(x) 99(x) 100(x) 101(x) 104(o) ..... 200(x) 400(o) ....
#
# 我們每天24小時(其實都少算了一點) 每當4年(累積) 我們就要把這些少算的時間(剛好一天) 補回來
#
# 妳補的其實也補多了 每當100年 這次就不用補了
#
# 以上面的規則補天數的話 妳到400年 又少一天
# ```

# %%
# 2000: O
# 1800: X
# 888: O
# 777: X
year = 2000

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("閏")
        else:
            print("平")
    else:
        print("閏")
else:
    print("平")
# Out:
# 閏

# %%
year = 2000
if year % 400 == 0:
    print("閏")
elif year % 100 == 0:
    print("平")
elif year % 4 == 0:
    print("閏")
else:
    print("平")
# Out:
# 閏

# %%
# 定義功能
# 參數: 只是先定義符號(名字) a(名字) = 3
def add(a, b):
    c = a + b
    return c
print(add(3, 5))
# Out:
# 8
